# %% [markdown]
# ## Data Importing

# %%
import pandas as pd
ABSEI = pd.read_csv(r"C:\Users\lukef\Desktop\SQL Files\SQLite.csv")

# Used SQLiteonline to import a data file from the CSO website
# The file consists of data from the Annual Business Survey of Economic Impact (ABSEI), collected by the Department of Enterprise, Trade and Employment 
# In SQILiteonlie I selected Ireland for Region to show only national data and excluded regional data
# I exported the new file to my local drive and imported it to the Jupyter notebook using the pandas pd.read_csv() function

ABSEI
# Out:
#                                       Statistic_Label  Year  \
# 0   Total Sales of Goods Produced and Services Pro...  2000
# 1   Total Sales of Goods Produced and Services Pro...  2000
# 2   Total Sales of Goods Produced and Services Pro...  2000
# 3   Total Sales of Goods Produced and Services Pro...  2001
# 4   Total Sales of Goods Produced and Services Pro...  2001
# ..                                                ...   ...
# 61  Total Sales of Goods Produced and Services Pro...  2020
# 62  Total Sales of Goods Produced and Services Pro...  2020
# 63  Total Sales of Goods Produced and Services Pro...  2021
# 64  Total Sales of Goods Produced and Services Pro...  2021
# 65  Total Sales of Goods Produced and Services Pro...  2021
#
#            Type_of_Ownership   Region          UNIT   VALUE
# 0   All Enterprise ownership  Ireland  Euro Million  102972
# 1            Irish ownership  Ireland  Euro Million   21924
# 2          Foreign ownership  Ireland  Euro Million   81048
# ...

# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\lukef\Documents\Researcher\BSA70.20230508T180539.csv.csv")
print(df)

# Pandas is a Python library used to analyse, clean and manipulate data
# Imported the csv file from the CSO website by downloading it to a local file first. I named the new dataframe 'df' to carry out data cleaning and analysis
# This dataset is the base which will be used for the rest of the notebook


df
# Out:
#                      STATISTIC Label  Year               Region         Sex  \
# 0    Headcount of Research Personnel  2017                State  Both sexes
# 1    Headcount of Research Personnel  2017                State  Both sexes
# 2    Headcount of Research Personnel  2017                State  Both sexes
# 3    Headcount of Research Personnel  2017                State  Both sexes
# 4    Headcount of Research Personnel  2017                State  Both sexes
# ..                               ...   ...                  ...         ...
# 175  Headcount of Research Personnel  2021  Eastern and Midland      Female
# 176  Headcount of Research Personnel  2021  Eastern and Midland      Female
# 177  Headcount of Research Personnel  2021  Eastern and Midland      Female
# 178  Headcount of Research Personnel  2021  Eastern and Midland      Female
# 179  Headcount of Research Personnel  2021  Eastern and Midland      Female
#
#                      Type of Researcher    UNIT  VALUE
# ...

# %% [markdown]
# ## Data Overview

# %%
df.info()

#There are 180 rows of data and 7 columns of data
#Data in the year and VALUE columns are integers while data in the Statistic Label, Region, Sex, Type of researcher and UNIT columns are objects
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   STATISTIC Label     180 non-null    object
#  1   Year                180 non-null    int64
#  2   Region              180 non-null    object
#  3   Sex                 180 non-null    object
#  4   Type of Researcher  180 non-null    object
#  5   UNIT                180 non-null    object
#  6   VALUE               180 non-null    int64
# dtypes: int64(2), object(5)
# memory usage: 10.0+ KB

# %%
df.shape
#There are 180 rows and 7 columns of data
# Out:
# (180, 7)

# %%
df.head()
#The first 5 rows of the dataset are displayed
# Out:
#                    STATISTIC Label  Year Region         Sex  \
# 0  Headcount of Research Personnel  2017  State  Both sexes
# 1  Headcount of Research Personnel  2017  State  Both sexes
# 2  Headcount of Research Personnel  2017  State  Both sexes
# 3  Headcount of Research Personnel  2017  State  Both sexes
# 4  Headcount of Research Personnel  2017  State  Both sexes
#
#                    Type of Researcher    UNIT  VALUE
# 0  All research and development staff  Number  27320
# 1           PhD qualified researchers  Number   2195
# 2                   Other researchers  Number  13410
# 3                         Technicians  Number   7391
# 4                       Support staff  Number   4324

# %%
df.columns

# Statistic Label: The headcount of research personnel
# Year: The year data was collected for (2017, 2019 and 2021)
# Region: The Regions are Northern and Western, Eastern and Midland, Southern and State
# Sex: Male, Female and Both Sexes
# Type of Researcher: The type of research personnel (Support staff, Technicians, Other researchers, PhD researchers and All research and development staff)
# Unit: The unit of the value (the number)
# Value: The number of researchers in that type
# Out:
# Index(['STATISTIC Label', 'Year', 'Region', 'Sex', 'Type of Researcher',
#        'UNIT', 'VALUE'],
#       dtype='object')

# %%
df.describe ()

# The smallest number of researchers in a category is 36
# The largest number of researchers in a category is 3,2961
# Out:
#               Year         VALUE
# count   180.000000    180.000000
# mean   2019.000000   3912.672222
# std       1.637548   5593.169896
# min    2017.000000     36.000000
# 25%    2017.000000    667.500000
# 50%    2019.000000   1720.500000
# 75%    2021.000000   4613.750000
# max    2021.000000  32961.000000

# %% [markdown]
# ## Data Cleaning

# %%
Researchers_df = df.copy()

# Made a copy of the dataset with a new name

# %%
Researchers_df = Researchers_df.sort_values(by = "Year", ascending = False,)

Researchers_df

# Ordered the dataset by descending year 
# The indices have also changed to reflect the change in order
# Out:
#                      STATISTIC Label  Year                Region         Sex  \
# 179  Headcount of Research Personnel  2021   Eastern and Midland      Female
# 149  Headcount of Research Personnel  2021  Northern and Western      Female
# 147  Headcount of Research Personnel  2021  Northern and Western      Female
# 146  Headcount of Research Personnel  2021  Northern and Western      Female
# 145  Headcount of Research Personnel  2021  Northern and Western      Female
# ..                               ...   ...                   ...         ...
# 36   Headcount of Research Personnel  2017              Southern        Male
# 35   Headcount of Research Personnel  2017              Southern        Male
# 34   Headcount of Research Personnel  2017              Southern  Both sexes
# 33   Headcount of Research Personnel  2017              Southern  Both sexes
# 0    Headcount of Research Personnel  2017                 State  Both sexes
#
# ...

# %%
Researchers_df.isnull()

# This is not useful as it only shows the first and last 5 rows. All values shown are False which means that there are no missing values below. True would mean that there are missing values
# Out:
#      STATISTIC Label   Year  Region    Sex  Type of Researcher   UNIT  VALUE
# 179            False  False   False  False               False  False  False
# 149            False  False   False  False               False  False  False
# 147            False  False   False  False               False  False  False
# 146            False  False   False  False               False  False  False
# 145            False  False   False  False               False  False  False
# ..               ...    ...     ...    ...                 ...    ...    ...
# 36             False  False   False  False               False  False  False
# 35             False  False   False  False               False  False  False
# 34             False  False   False  False               False  False  False
# 33             False  False   False  False               False  False  False
# 0              False  False   False  False               False  False  False
#
# [180 rows x 7 columns]

# %%
Researchers_df.isnull().sum()

# This is more useful as it shows the amount of null values across each column in the dataset - which there are none
# Out:
# STATISTIC Label       0
# Year                  0
# Region                0
# Sex                   0
# Type of Researcher    0
# UNIT                  0
# VALUE                 0
# dtype: int64

# %%
Researchers_df.duplicated().sum()

# There are no duplicate values in the dataset
# Out:
# 0

# %%
Researchers_df.dropna()

# This is the formula that would have been used if there were null values in the dataset. As the number of rows is the same as df.shape - none have been dropped because no rows have null values
# Out:
#                      STATISTIC Label  Year                Region         Sex  \
# 179  Headcount of Research Personnel  2021   Eastern and Midland      Female
# 149  Headcount of Research Personnel  2021  Northern and Western      Female
# 147  Headcount of Research Personnel  2021  Northern and Western      Female
# 146  Headcount of Research Personnel  2021  Northern and Western      Female
# 145  Headcount of Research Personnel  2021  Northern and Western      Female
# ..                               ...   ...                   ...         ...
# 36   Headcount of Research Personnel  2017              Southern        Male
# 35   Headcount of Research Personnel  2017              Southern        Male
# 34   Headcount of Research Personnel  2017              Southern  Both sexes
# 33   Headcount of Research Personnel  2017              Southern  Both sexes
# 0    Headcount of Research Personnel  2017                 State  Both sexes
#
# ...

# %%
Researchers_df.fillna("No Data")
print(Researchers_df)

# This would input 'No data' for all rows that contained null values. I would then check it using Researchers_df.head() or _df.tail() to see if 'No data' had been input. As this is a relatively small dataset dropping multiple rows could inhibit data analysis
# Out:
#                      STATISTIC Label  Year                Region         Sex  \
# 179  Headcount of Research Personnel  2021   Eastern and Midland      Female
# 149  Headcount of Research Personnel  2021  Northern and Western      Female
# 147  Headcount of Research Personnel  2021  Northern and Western      Female
# 146  Headcount of Research Personnel  2021  Northern and Western      Female
# 145  Headcount of Research Personnel  2021  Northern and Western      Female
# ..                               ...   ...                   ...         ...
# 36   Headcount of Research Personnel  2017              Southern        Male
# 35   Headcount of Research Personnel  2017              Southern        Male
# 34   Headcount of Research Personnel  2017              Southern  Both sexes
# 33   Headcount of Research Personnel  2017              Southern  Both sexes
# 0    Headcount of Research Personnel  2017                 State  Both sexes
#
# ...

# %%
Researchers2021_State_M_F = Researchers_df[((Researchers_df["Region"] == "State") & (Researchers_df["Sex"] == "Male" )) & (Researchers_df["Year"] == 2021) | ((Researchers_df["Region"] == "State") & (Researchers_df["Sex"] == "Female" )) & (Researchers_df["Year"] == 2021)]
Researchers2021_State_M_F

# shows the data for 2021 for Male and Female researchers in the state for 2021 using and/or functions
# This can be altered to select different values in the columns
# Out:
#                      STATISTIC Label  Year Region     Sex  \
# 134  Headcount of Research Personnel  2021  State  Female
# 133  Headcount of Research Personnel  2021  State  Female
# 132  Headcount of Research Personnel  2021  State  Female
# 131  Headcount of Research Personnel  2021  State  Female
# 130  Headcount of Research Personnel  2021  State  Female
# 129  Headcount of Research Personnel  2021  State    Male
# 128  Headcount of Research Personnel  2021  State    Male
# 127  Headcount of Research Personnel  2021  State    Male
# 126  Headcount of Research Personnel  2021  State    Male
# 125  Headcount of Research Personnel  2021  State    Male
#
#                      Type of Researcher    UNIT  VALUE
# 134                       Support staff  Number   2499
# 133                         Technicians  Number   2210
# 132                   Other researchers  Number   3420
# 131           PhD qualified researchers  Number    677
# ...

# %% [markdown]
# ## Data Manipulation

# %%
Researchers2021_State_M_F = Researchers_df[((Researchers_df["Region"] == "State") & (Researchers_df["Sex"] == "Male" )) & (Researchers_df["Year"] == 2021) | ((Researchers_df["Region"] == "State") & (Researchers_df["Sex"] == "Female" )) & (Researchers_df["Year"] == 2021)]
Researchers2021_State_M_F

# shows the data for 2021 for Male and Female researchers in the state for 2021 using and/or functions
# This can be altered to select different values in the columns
# Out:
#                      STATISTIC Label  Year Region     Sex  \
# 134  Headcount of Research Personnel  2021  State  Female
# 133  Headcount of Research Personnel  2021  State  Female
# 132  Headcount of Research Personnel  2021  State  Female
# 131  Headcount of Research Personnel  2021  State  Female
# 130  Headcount of Research Personnel  2021  State  Female
# 129  Headcount of Research Personnel  2021  State    Male
# 128  Headcount of Research Personnel  2021  State    Male
# 127  Headcount of Research Personnel  2021  State    Male
# 126  Headcount of Research Personnel  2021  State    Male
# 125  Headcount of Research Personnel  2021  State    Male
#
#                      Type of Researcher    UNIT  VALUE
# 134                       Support staff  Number   2499
# 133                         Technicians  Number   2210
# 132                   Other researchers  Number   3420
# 131           PhD qualified researchers  Number    677
# ...

# %%
import numpy as np
np_Type = np.array(["Female Support Staff", "Female Technicians", "Female Other researchers", "Female PhD qualified researchers", "Female All research and development staff"])
np_Value = np.array([2499, 2210, 3420, 677, 8809])

# created arrays for Type of Researcher and Value

print(np_Type)
print(np_Value)
# Out:
# ['Female Support Staff' 'Female Technicians' 'Female Other researchers'
#  'Female PhD qualified researchers'
#  'Female All research and development staff']
# [2499 2210 3420  677 8809]

# %%
Female2021 = {"Female Support Staff":2499, "Female Technicians":2210, "Female Other researchers": 3420, "Female PhD qualified researchers": 677, "Female All research and development staff": 8809}
print(Female2021)

for rows in Female2021.items(): 
    print(rows)

# created a dictionary for the types of female researchers in the state in 2021 (key) and the corresponding amount (value)
# used the .items() method in the for loop on the dictionary to give the key and value for each row
# Out:
# {'Female Support Staff': 2499, 'Female Technicians': 2210, 'Female Other researchers': 3420, 'Female PhD qualified researchers': 677, 'Female All research and development staff': 8809}
# ('Female Support Staff', 2499)
# ('Female Technicians', 2210)
# ('Female Other researchers', 3420)
# ('Female PhD qualified researchers', 677)
# ('Female All research and development staff', 8809)

# %%
Male2021 = {"Male Support Staff": 5031, "Male Technicians": 6481, "Male Other researchers": 10827, "PhD qualified researchers": 1813, "Male All research and development staff": 24153}
for rows in Male2021.items(): 
    print(rows)
# Out:
# ('Male Support Staff', 5031)
# ('Male Technicians', 6481)
# ('Male Other researchers', 10827)
# ('PhD qualified researchers', 1813)
# ('Male All research and development staff', 24153)

# %%
def Merge(Female2021, Male2021):
    result = Female2021 | Male2021
    return result


All = {**Female2021, **Male2021}
print(All)

# Joined the two dictionaries into one by using the ** method. This concenated the two dictionaries
# Out:
# {'Female Support Staff': 2499, 'Female Technicians': 2210, 'Female Other researchers': 3420, 'Female PhD qualified researchers': 677, 'Female All research and development staff': 8809, 'Male Support Staff': 5031, 'Male Technicians': 6481, 'Male Other researchers': 10827, 'PhD qualified researchers': 1813, 'Male All research and development staff': 24153}

# %% [markdown]
# ## Data Visualisation

# %%
Researchers_All_Years_Male = Researchers_df[((Researchers_df["Region"] == "State") & (Researchers_df["Sex"] == "Male" ) & (Researchers_df["Type of Researcher"] == "All research and development staff"))]
Researchers_All_Years_Male

# All male R&D staff in the state for 2017, 2019 and 2021
# This dataset is used in Graph no.1
# Out:
#                      STATISTIC Label  Year Region   Sex  \
# 125  Headcount of Research Personnel  2021  State  Male
# 65   Headcount of Research Personnel  2019  State  Male
# 5    Headcount of Research Personnel  2017  State  Male
#
#                      Type of Researcher    UNIT  VALUE
# 125  All research and development staff  Number  24153
# 65   All research and development staff  Number  20227
# 5    All research and development staff  Number  20190

# %%
Researchers_All_Years_Female = Researchers_df[((Researchers_df["Region"] == "State") & (Researchers_df["Sex"] == "Female" ) & (Researchers_df["Type of Researcher"] == "All research and development staff"))]
Researchers_All_Years_Female

# All female R&D staff in the state for 2017, 2019 and 2021
# This dataset is used in Graph no.1
# Out:
#                      STATISTIC Label  Year Region     Sex  \
# 130  Headcount of Research Personnel  2021  State  Female
# 70   Headcount of Research Personnel  2019  State  Female
# 10   Headcount of Research Personnel  2017  State  Female
#
#                      Type of Researcher    UNIT  VALUE
# 130  All research and development staff  Number   8809
# 70   All research and development staff  Number   7528
# 10   All research and development staff  Number   7130

# %%
Researchers_All_Years_Both = Researchers_df[((Researchers_df["Region"] == "State") & (Researchers_df["Sex"] == "Both sexes" ) & (Researchers_df["Type of Researcher"] == "All research and development staff"))]
Researchers_All_Years_Both
# Total R&D staff in the state for 2017, 2019 and 2021
# This dataset is used in Graph no.1
# Out:
#                      STATISTIC Label  Year Region         Sex  \
# 120  Headcount of Research Personnel  2021  State  Both sexes
# 60   Headcount of Research Personnel  2019  State  Both sexes
# 0    Headcount of Research Personnel  2017  State  Both sexes
#
#                      Type of Researcher    UNIT  VALUE
# 120  All research and development staff  Number  32961
# 60   All research and development staff  Number  27755
# 0    All research and development staff  Number  27320

# %%
import pandas as pd
import matplotlib.pyplot as plt 

plt.plot(Researchers_All_Years_Male["Year"], Researchers_All_Years_Male["VALUE"], color = "blue", marker = "o", label = "Male", linestyle = "--")
plt.plot(Researchers_All_Years_Female["Year"], Researchers_All_Years_Female["VALUE"], color = "red", marker = "o", label = "Female", linestyle = "--")
plt.plot(Researchers_All_Years_Both["Year"], Researchers_All_Years_Both["VALUE"], color = "green", marker = "o", label ="Both", linestyle = "--")
plt.xlim(2016, 2022)
plt.title(" Graph 1: All Research and Development Staff Across Years", fontsize = 20)
plt.xlabel ("Year")
plt.ylabel ("Number of Researchers")
plt.rcParams["figure.figsize"] = (16,8)
plt.grid(True)
plt.show

# a lineplot which shows the number of Male and Female R&D personnel in the state across 2017, 2019 and 2021
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Researchers_2021 = Researchers_df[((Researchers_df["Region"] == "State") & (Researchers_df["Sex"] == "Male" ) & (Researchers_df["Year"] == 2021))]
Researchers_2021

# The number of male researchers in the state for 2021 by type including the total number of R&D staff
# This dataset is used in Graph no.2
# There are considerably more male R&D staff than female R&D staff and male researchers are increasing at a faster rate in the period in which the data covers
# Out:
#                      STATISTIC Label  Year Region   Sex  \
# 129  Headcount of Research Personnel  2021  State  Male
# 128  Headcount of Research Personnel  2021  State  Male
# 127  Headcount of Research Personnel  2021  State  Male
# 126  Headcount of Research Personnel  2021  State  Male
# 125  Headcount of Research Personnel  2021  State  Male
#
#                      Type of Researcher    UNIT  VALUE
# 129                       Support staff  Number   5031
# 128                         Technicians  Number   6481
# 127                   Other researchers  Number  10827
# 126           PhD qualified researchers  Number   1813
# 125  All research and development staff  Number  24153

# %%
import matplotlib.pyplot as plt 
import pandas as pd

colors = ["green", "blue", "red", "brown", "pink"]
plt.bar(Researchers_2021["Type of Researcher"], Researchers_2021["VALUE"], color=colors)
plt.title("Graph 2: Number of Male Researchers by Type (2021)", fontsize = 20)
plt.xlabel("Type of Researcher", fontsize = 12)
plt.ylabel("Number", fontsize = 12)
plt.grid(True)
plt.xticks(fontsize = 10)
plt.rcParams["figure.figsize"] = (16,8)
plt.show

# added in a grid to make the chart easier to read
# shows the total number of researchers
# changed the width and length of the graph so labels could be read easily 
# increased the size of the x and y axes labels to distinguish them from graph labels
# The number of male R&D staff from highest to lowest is the following: Other Researchers, Technicians, Support Staff and PhD qualified researchers
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
Researchers_2021_Type = Researchers_2021.drop(125)
Researchers_2021_Type

# dropped the All research and development staff using the row index
# Male researchers in the state broken down by type excluding total number of R&D staff
# This dataset is used in Graph no.3
# Out:
#                      STATISTIC Label  Year Region   Sex  \
# 129  Headcount of Research Personnel  2021  State  Male
# 128  Headcount of Research Personnel  2021  State  Male
# 127  Headcount of Research Personnel  2021  State  Male
# 126  Headcount of Research Personnel  2021  State  Male
#
#             Type of Researcher    UNIT  VALUE
# 129              Support staff  Number   5031
# 128                Technicians  Number   6481
# 127          Other researchers  Number  10827
# 126  PhD qualified researchers  Number   1813

# %%
Researchers_2021_Type.groupby(["Type of Researcher"]).sum().plot(kind="pie", y = "VALUE", autopct='%1.1f%%')
plt.legend(loc="upper left")
plt.title("Graph 3: Male Researchers by Type (2021)", fontsize = 20)
plt.ylabel("")
plt.show()

# created a pie chart to show the proportion of male R&D staff types working in the state in 2021 
# moved the legend so all quadrant labels could be read 
# removed the VALUE label on the y-axis
# Other researchers make up the largest proportion of Male R&D staff in the State in 2021
